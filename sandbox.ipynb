# %%
import torch
import torch.nn as nn
from functions import build_vocab, encode, PAD_ID

# %%
# Out:
# 3D-Embeddings der Absätze:
# tensor([[ 0.3103,  0.2917, -1.0150],
#         [ 0.2173,  0.0334, -0.3344],
#         [-0.1790, -0.4550,  0.2806]])
